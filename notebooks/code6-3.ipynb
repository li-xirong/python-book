# %% [markdown]
# # 绘制历年人大工商管理专业在福建省理科录取分数线折线图

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots()
years = list(range(2015, 2024))
scores = [671, 645, 608, 664, 650, 673, 664, 658, 671] 
axes.plot(years, scores)
