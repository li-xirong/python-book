# %% [markdown]
# # 提取性别标签的CLIP嵌入特征

# %%
# 运行准备：复用p5lib加载本地CLIP模型
from p5lib.ch5 import load_sentence_model

model = load_sentence_model("./fm/clip-ViT-B-32")

# %%
label_txt = ['a female portrait', 'a male portrait']
label_emb = model.encode(label_txt)
