# %% [markdown]
# # 尝试向不存在的 URL 发送请求

# %%
import requests

try:
    response = requests.get("http://www.doesnotexist.html")
    print(response.status_code)
except Exception as e:
    print(e)
# Out:
# 502
