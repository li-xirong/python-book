# %% [markdown]
# # Tensor形变操作

# %%
import torch

a = torch.rand((4, 4))
b = a.reshape(-1, 8)
c = a.reshape(2, -1)
d = a.reshape(-1)
print(a.shape, b.shape, c.shape, d.shape)
# Out:
# torch.Size([4, 4]) torch.Size([2, 8]) torch.Size([2, 8]) torch.Size([16])
