# %% [markdown]
# # 查看Tensor对象的属性

# %%
import torch

x = torch.rand((3, 4))
print(x)
print(x.ndim, x.shape, x.dtype, x.device, x.requires_grad)
# Out:
# tensor([[0.2654, 0.9364, 0.7855, 0.7708],
#         [0.7168, 0.9506, 0.1704, 0.9710],
#         [0.1996, 0.5024, 0.9559, 0.5843]])
# 2 torch.Size([3, 4]) torch.float32 cpu False
