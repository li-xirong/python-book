# %% [markdown]
# # 绘制经PCA降维后的Iris数据散点图

# %%
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Step 1. 加载Iris 数据集
iris = datasets.load_iris()
X = iris.data 
y = iris.target
# Step 2. 数据标准化
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
# Step 3. PCA模型训练
pca = PCA(n_components=2)
pca.fit(X_scaled)
# Step 4. 降维
Z = pca.transform(X_scaled)
print(f"输入数据形状: {X.shape}, 降维后数据形状: {Z.shape}")
# Out:
# 输入数据形状: (150, 4), 降维后数据形状: (150, 2)

# %%
labels = iris.target_names  # ['setosa', 'versicolor', 'virginica']
colors = ['red', 'green', 'blue']
markers = ['o', '^', 's']
fig, axes = plt.subplots()
for i, label in enumerate(labels):
    axes.plot(Z[y==i,0], Z[y==i, 1], linestyle='none', marker=markers[i], markerfacecolor=colors[i], alpha=0.6, label=label)
axes.legend(loc='best')
axes.set_xlabel('PC1')
axes.set_ylabel('PC2')
plt.grid(True)
